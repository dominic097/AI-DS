# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Display all images in subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Original grayscale
axes[0, 0].imshow(img_grey, cmap='gray')
axes[0, 0].set_title('Original Grayscale')
axes[0, 0].axis('off')

# Ocean colormap
axes[0, 1].imshow(cv2.cvtColor(im_color, cv2.COLOR_BGR2RGB))
axes[0, 1].set_title('Ocean Colormap')
axes[0, 1].axis('off')

# Winter colormap
axes[1, 0].imshow(cv2.cvtColor(im_color2, cv2.COLOR_BGR2RGB))
axes[1, 0].set_title('Winter Colormap')
axes[1, 0].axis('off')

# Ocean colormap (second)
axes[1, 1].imshow(cv2.cvtColor(im_color3, cv2.COLOR_BGR2RGB))
axes[1, 1].set_title('Ocean Colormap (2)')
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Full color Image processing

# %%
img = cv2.imread('./tree_1308-36471.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Split into RGB channels
r, g, b = cv2.split(img)

# Create 2x2 subplot
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Original color image
axes[0, 0].imshow(img)
axes[0, 0].set_title('Original Color Image')
axes[0, 0].axis('off')

# Red channel
axes[0, 1].imshow(r, cmap='gray')
axes[0, 1].set_title('Red Channel')
axes[0, 1].axis('off')

# Green channel
axes[1, 0].imshow(g, cmap='gray')
axes[1, 0].set_title('Green Channel')
axes[1, 0].axis('off')

# Blue channel
axes[1, 1].imshow(b, cmap='gray')
axes[1, 1].set_title('Blue Channel')
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()
