# %% [markdown]
# ## 1. Using Spacy

# %%
#Install Spacy
# !pip install spacy --quiet

# %%
#To download smaller model for English, run the following
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 98.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
# Load pre-trained model (e.g., 'en_core_web_sm')
nlp=spacy.load("en_core_web_sm")

# %% [markdown]
# ## 2. NER

# %%
# Example text
text="Bharath is an American politician who served as the 44th President of the United States from 2009 to 2017. He is the first African American to have served as president, as well as the first born outside the contiguous United States."

# %%
# Process the text
doc3=nlp(text)

# %% [markdown]
# What Happens Internally?
# Tokenization: Splits the text into words, punctuation, etc.
#
# POS Tagging: Assigns grammatical categories (noun, verb, etc.).
#
# Dependency Parsing: Identifies relationships between words.
#
# Named Entity Recognition (NER): Identifies proper names, organizations, dates, etc.
#
# Lemmatization: Converts words to their base forms.

# %%
from spacy import displacy
displacy.render(doc3, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Bharath is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  politician who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  President of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
# ...

# %%
# Extract entities
entities = [(ent.text, ent.label_) for ent in doc3.ents]
print(entities)
# Out:
# [('American', 'NORP'), ('44th', 'ORDINAL'), ('the United States', 'GPE'), ('2009', 'DATE'), ('first', 'ORDINAL'), ('African American', 'NORP'), ('first', 'ORDINAL'), ('United States', 'GPE')]

# %%
import pandas as pd
# Example: Creating a DataFrame
data = []
for ent in doc3.ents:
    data.append({"Entity": ent.text, "Label": ent.label_})
df = pd.DataFrame(data)
print(df)
# Out:
#               Entity    Label
# 0           American     NORP
# 1               44th  ORDINAL
# 2  the United States      GPE
# 3               2009     DATE
# 4              first  ORDINAL
# 5   African American     NORP
# 6              first  ORDINAL
# 7      United States      GPE

# %% [markdown]
# ## 3. Part of Speech (POS) Tagging

# %%
#Process a sentence
doc = nlp('She saw a bear. She was very afraid.')

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
#Print POS tags for each word 2 for word in doc:
for word in doc:
  print (word, word.pos_)
# Out:
# She PRON
# saw VERB
# a DET
# bear NOUN
# . PUNCT
# She PRON
# was AUX
# very ADV
# afraid ADJ
# . PUNCT

# %%
#Check another document
doc2 = nlp('Your effort will bear fruit.')
for word in doc2:
  print (word, word.pos_)
# Out:
# Your PRON
# effort NOUN
# will AUX
# bear VERB
# fruit NOUN
# . PUNCT

# %% [markdown]
# ## 4. Dependency Parsing in spaCy

# %%
# Example sentence
text = "The quick brown fox jumps over the lazy dog."
# Process text
doc = nlp(text)
# Print dependencies
for token in doc:
    print(f"{token.text} → {token.dep_} → {token.head.text}")
# Out:
# The → det → fox
# quick → amod → fox
# brown → amod → fox
# fox → nsubj → jumps
# jumps → ROOT → jumps
# over → prep → jumps
# the → det → dog
# lazy → amod → dog
# dog → pobj → over
# . → punct → jumps

# %%
from spacy import displacy
# Render the dependency tree
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b0eac3ec72204e52bc69fb0a21612b3a-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...
