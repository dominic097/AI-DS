# %%
# !pip install pandas numpy transformers scikit-learn

import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: pandas in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (3.0.1)
# Requirement already satisfied: numpy in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (2.4.2)
# Requirement already satisfied: transformers in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (5.2.0)
# Requirement already satisfied: scikit-learn in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer-slim->transformers) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->transformers) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers) (0.1.2)

# %% [markdown]
# ## Download Real SMS Spam Dataset from Kaggle
#
# To use Kaggle API:
# 1. Create a Kaggle account at https://www.kaggle.com
# 2. Go to Account Settings → API → Create New Token
# 3. This downloads `kaggle.json` - place it in `~/.kaggle/` directory
# 4. Run: `chmod 600 ~/.kaggle/kaggle.json`

# %%
# Install Kaggle API
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (2.0.0)
# Requirement already satisfied: bleach in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: packaging in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (26.0)
# Requirement already satisfied: protobuf in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (6.33.5)
# Requirement already satisfied: python-dateutil in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: tqdm in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests->kaggle) (2026.1.4)

# %%
# Download UCI SMS Spam Collection Dataset from Kaggle
# Make sure you have set up your Kaggle API credentials first!
# !kaggle datasets download -d uciml/sms-spam-collection-dataset -p ./data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset
# License(s): unknown
# Downloading sms-spam-collection-dataset.zip to ./data
# 100%|█████████████████████████████████████████| 211k/211k [00:00<00:00, 253kB/s]

# %%
# Load the real SMS Spam dataset
sms_df_real = pd.read_csv('./data/spam.csv', encoding='latin-1')

# The dataset has extra unnamed columns, keep only the first two
sms_df_real = sms_df_real[['v1', 'v2']]
sms_df_real.columns = ['label', 'text']

print(f"Dataset shape: {sms_df_real.shape}")
print(f"\nLabel distribution:")
print(sms_df_real['label'].value_counts())
sms_df_real.head()
# Out:
# Dataset shape: (5572, 2)
#
# Label distribution:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Now use the real dataset (sms_df_real) instead of synthetic data
#
# This UCI SMS Spam Collection contains 5,574 real SMS messages with realistic patterns. You should see more realistic accuracy scores (typically 95-98% instead of 100%).

# %%
# Create numeric labels for the real dataset
sms_df_real['label_num'] = sms_df_real['label'].map({'ham': 0, 'spam': 1})
print("Real dataset with label_num column:")
sms_df_real.head()
# Out:
# Real dataset with label_num column:
#   label                                               text  label_num
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %%
sms_df=pd.read_csv('GL Notes/sms_spam_synthetic.csv', encoding='latin-1')
sms_df.shape
sms_df.head()   
sms_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5000 non-null   str
#  1   label   5000 non-null   str
# dtypes: str(2)
# memory usage: 78.3 KB

# %%
sms_df.sample(n=15)
# Out:
#                                                    text label
# 877                             Please check email done   ham
# 4520                                     See you soon 2   ham
# 3895                 Please check email 10 thanks class   ham
# 651                                    Reached home yup   ham
# 726                         Reached home 24 sure office   ham
# 845                   Please check email 14 please home   ham
# 476                         Lunch at 1 pm works 19 home   ham
# 1238                           Where are you? 9 ok home   ham
# 1728                      Call me when you are free bus   ham
# 1412                               Good night ok office   ham
# 4557                                     Where are you?   ham
# 3456                                         Good night   ham
# 4460                             Happy birthday! 13 yup   ham
# 4446                                      On my way yup   ham
# 4440  $$$ VOUCHER GIFT VOUCHER $$$ EXCLUSIVE DISCOUN...  spam

# %%
sms_df.loc[0, "text"]
# Out:
# 'Please check email yup shop'

# %%
sms_df.groupby("label").size()
print("Number of ham messages:", sms_df[sms_df["label"]=="ham"].shape[0])
print("Number of spam messages:", sms_df[sms_df["label"]=="spam"].shape[0])

print("probablity of Ham messages: <-- should be close to 0.82 which is the base level accuracy if we predict all messages as ham   ")
print(4100/(4100+900))
print("probablity of Spam messages:")
print(900/(4100+900))
# Out:
# Number of ham messages: 4100
# Number of spam messages: 900
# probablity of Ham messages: <-- should be close to 0.82 which is the base level accuracy if we predict all messages as ham
# 0.82
# probablity of Spam messages:
# 0.18

# %%
msg_num = np.random.randint(0, len(sms_df))
print("Randomly selected message:")
print(sms_df.loc[msg_num, "text"])
print("Label:", sms_df.loc[msg_num, "label"])

sms_df.isnull().sum()
# Out:
# Randomly selected message:
# On my way 9
# Label: ham
# text     0
# label    0
# dtype: int64

# %%
sms_df['label_num'] = sms_df['label'].map({'ham': 0, 'spam': 1})
sms_df.head()
sms_df.sample(n=15)
# Out:
#                                                    text label  label_num
# 2522                Can you send the file? 5 thanks gym   ham          0
# 3082                        Meeting moved to tomorrow 5   ham          0
# 4692  GUARANTEED DEAL PRIZE WIN WIN ACT OFFER REPLY ...  spam          1
# 262                                 See you soon please   ham          0
# 4108                                 Reached home 13 ok   ham          0
# 4008                Lunch at 1 pm works 21 please class   ham          0
# 4438                       Meeting moved to tomorrow 28   ham          0
# 1674                         Lunch at 1 pm works thanks   ham          0
# 1057  DEAL REPLY HTTP://BIT.LY/ PRIZE REPLY IMMEDIAT...  spam          1
# 2843                  I'll be late by 10 minutes thanks   ham          0
# 75                                 Happy birthday! sure   ham          0
# 4276                         Let's catch up later class   ham          0
# 3817                    Are we meeting today? 15 office   ham          0
# 4879                                  Good night thanks   ham          0
# 4919                               Please check email 6   ham          0

# %% [markdown]
# # Create Training & Test DataSet

# %%
sms_train, sms_test, y_train, y_test = train_test_split(sms_df_real['text'], sms_df_real['label_num'], random_state=42)
sms_train.reset_index(inplace=  True, drop=True)
sms_test.reset_index(inplace=  True, drop=True)
y_train.reset_index(inplace=  True, drop=True)
y_test.reset_index(inplace=  True, drop=True)

print(sms_test.shape)
print(y_test.shape)
# Out:
# (1393,)
# (1393,)

# %% [markdown]
# # Tokenization & Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cvect = CountVectorizer()
sms_train.head()
# Out:
# 0                                    U can call now...
# 1    Tell them u have a headache and just want to u...
# 2    Never try alone to take the weight of a tear t...
# 3    Raji..pls do me a favour. Pls convey my Birthd...
# 4              What time. IÛ÷m out until prob 3 or so
# Name: text, dtype: str

# %%
cvect.fit(sms_train)

cvect.vocabulary_
# Out:
# {'can': 1576,
#  'call': 1552,
#  'now': 4648,
#  'tell': 6464,
#  'them': 6532,
#  'have': 3245,
#  'headache': 3257,
#  'and': 919,
#  'just': 3738,
#  'want': 7067,
#  'to': 6640,
#  'use': 6909,
#  'hour': 3395,
#  'of': 4691,
#  'sick': 5883,
#  'time': 6610,
#  'never': 4566,
#  'try': 6761,
#  'alone': 883,
#  'take': 6401,
#  'the': 6524,
#  'weight': 7133,
#  'tear': 6449,
#  'that': 6519,
#  'comes': 1853,
#  'out': 4803,
#  'ur': 6893,
#  'heart': 3266,
#  'falls': 2681,
#  'through': 6583,
#  'eyes': 2656,
#  'always': 895,
#  'remember': 5445,
#  'stupid': 6260,
#  'friend': 2917,
#  'is': 3610,
#  'here': 3299,
#  'share': 5805,
#  'bslvyl': 1482,
#  'raji': 5318,
#  'pls': 5040,
#  'do': 2292,
#  'me': 4236,
#  'favour': 2713,
#  'convey': 1936,
#  'my': 4482,
#  'birthday': 1319,
#  'wishes': 7222,
#  'nimya': 4590,
#  'today': 6645,
#  'her': 3298,
#  'what': 7163,
#  'until': 6873,
#  'prob': 5200,
#  'or': 4772,
#  'so': 6010,
#  'hi': 3310,
#  'its': 3628,
#  'kate': 3763,
#  'it': 3621,
#  'was': 7078,
#  'lovely': 4062,
#  'see': 5726,
#  'you': 7388,
#  'tonight': 6672,
#  'ill': 3490,
#  'phone': 4970,
#  'tomorrow': 6663,
#  'got': 3100,
#  'sing': 5909,
#  'guy': 3175,
#  'gave': 2994,
#  'his': 3325,
#  'card': 1596,
#  'xxx': 7338,
#  'as': 1034,
#  'usual': 6919,
#  'iam': 3450,
#  'fine': 2772,
#  'happy': 3226,
#  'amp': 910,
#  'doing': 2318,
#  'well': 7142,
#  'nope': 4620,
#  'watching': 7089,
#  'tv': 6783,
#  'at': 1067,
#  'home': 3354,
#  'not': 4634,
#  'going': 3072,
#  'bored': 1391,
#  'ps': 5246,
#  'no': 4601,
#  'grown': 3153,
#  'up': 6875,
#  'right': 5539,
#  'wat': 7084,
#  'tht': 6591,
#  'incident': 3517,
#  'are': 1000,
#  'awake': 1120,
#  'there': 6541,
#  'snow': 6006,
#  'she': 5812,
#  'good': 3082,
#  'wondering': 7259,
#  'if': 3478,
#  'wont': 7261,
#  'say': 5672,
#  'but': 1519,
#  'smiling': 5983,
#  'how': 3401,
#  'coping': 1945,
#  'with': 7228,
#  'long': 4026,
#  'distance': 2278,
#  'intrepid': 3584,
#  'duo': 2411,
#  'great': 3135,
#  'both': 1399,
#  'soon': 6050,
#  'am': 897,
#  'in': 3512,
#  'gobi': 3064,
#  'arts': 1030,
#  'college': 1840,
#  'your': 7394,
#  'credits': 2007,
#  'been': 1249,
#  'topped': 6686,
#  'for': 2851,
#  'http': 3415,
#  'www': 7321,
#  'bubbletext': 1488,
#  'com': 1845,
#  'renewal': 5460,
#  'pin': 4999,
#  'tgxxrz': 6507,
#  'thought': 6573,
#  'put': 5272,
#  'back': 1152,
#  'box': 1407,
#  'wnt': 7249,
#  'buy': 1524,
#  'bmw': 1367,
#  'car': 1595,
#  'urgently': 6898,
#  'vry': 7019,
#  'urgent': 6897,
#  'hv': 3443,
#  'shortage': 5850,
#  'lt': 4081,
#  'gt': 3158,
#  'lacs': 3841,
#  'source': 6072,
#  'arng': 1016,
#  'dis': 2263,
#  'amt': 914,
#  'thats': 6521,
#  'mobile': 4366,
#  'has': 3236,
#  'added': 780,
#  'their': 6529,
#  'contact': 1922,
#  'list': 3980,
#  'on': 4733,
#  'fullonsms': 2949,
#  'place': 5011,
#  'send': 5751,
#  'free': 2895,
#  'sms': 5991,
#  'people': 4931,
#  'more': 4407,
#  'visit': 6996,
#  'easy': 2436,
#  'ah': 838,
#  'sen': 5750,
#  'selected': 5738,
#  'means': 4241,
#  'know': 3816,
#  'lacking': 3840,
#  'most': 4414,
#  'this': 6562,
#  'particular': 4881,
#  'dramastorm': 2360,
#  'details': 2205,
#  'part': 4879,
#  'worried': 7277,
#  'about': 730,
#  'business': 1516,
#  'probably': 5201,
#  'earlier': 2424,
#  'than': 6509,
#  'station': 6181,
#  'where': 7170,
#  'think': 6553,
#  'sorry': 6057,
#  'meeting': 4255,
#  'll': 3996,
#  'later': 3875,
#  'forwarded': 2877,
#  'from': 2931,
#  '21870000': 342,
#  'mailbox': 4148,
#  'messaging': 4285,
#  'alert': 868,
#  '40': 451,
#  'matches': 4209,
#  'please': 5032,
#  '09056242159': 166,
#  'retrieve': 5518,
#  'messages': 4284,
#  'cc100p': 1641,
#  'min': 4307,
#  'another': 936,
#  'job': 3694,
#  'one': 4738,
#  'hospital': 3385,
#  'data': 2101,
#  'analysis': 918,
#  'something': 6034,
#  'starts': 6174,
#  'monday': 4392,
#  'sure': 6337,
#  'when': 7167,
#  'thesis': 6543,
#  'will': 7203,
#  'finished': 2777,
#  'entry': 2534,
#  'gr8prizes': 3114,
#  'wkly': 7241,
#  'comp': 1865,
#  'chance': 1669,
#  'win': 7206,
#  'latest': 3876,
#  'nokia': 4609,
#  '8800': 666,
#  'psp': 5248,
#  '250': 354,
#  'cash': 1621,
#  'every': 2584,
#  'wk': 7237,
#  'txt': 6793,
#  '80878': 617,
#  '08715705022': 124,
#  'carlos': 1611,
#  'vibrate': 6967,
#  'acting': 767,
#  'might': 4300,
#  'hear': 3264,
#  'texts': 6506,
#  'smoking': 5989,
#  'while': 7176,
#  'wylie': 7322,
#  'smokes': 5987,
#  'too': 6676,
#  'much': 4453,
#  'justify': 3739,
#  'ruining': 5599,
#  'shit': 5832,
#  'new': 4567,
#  'video': 6971,
#  'phone750': 4971,
#  'anytime': 958,
#  'any': 949,
#  'network': 4562,
#  'mins': 4321,
#  '150': 292,
#  'text': 6496,
#  'only': 4744,
#  'five': 2794,
#  'pounds': 5121,
#  'per': 4933,
#  'week': 7125,
#  '08000776320': 46,
#  'reply': 5475,
#  'delivery': 2167,
#  'sounds': 6069,
#  'then': 6536,
#  'other': 4793,
#  'special': 6087,
#  'number': 4660,
#  'live': 3989,
#  '11': 257,
#  'oh': 4711,
#  'fuck': 2939,
#  'juswoke': 3740,
#  'bed': 1244,
#  'boatin': 1370,
#  'docks': 2296,
#  'slept': 5956,
#  'wid': 7192,
#  '25': 353,
#  'year': 7361,
#  'old': 4727,
#  'spinout': 6111,
#  'giv': 3045,
#  'da': 2073,
#  'gossip': 3099,
#  'l8r': 3831,
#  'knock': 3814,
#  'whose': 7186,
#  '80082': 608,
#  'enter': 2524,
#  'weekly': 7129,
#  'draw': 2363,
#  'gift': 3033,
#  'voucher': 7016,
#  'store': 6221,
#  'yr': 7405,
#  'choice': 1748,
#  'cs': 2024,
#  'tkls': 6628,
#  'age16': 829,
#  'stoptxtstopå': 6220,
#  '50': 506,
#  'tessy': 6490,
#  'favor': 2711,
#  'dnt': 2291,
#  'forget': 2859,
#  'shijas': 5822,
#  'dice': 2223,
#  'art': 1028,
#  'class': 1774,
#  'thru': 6589,
#  'thanks': 6513,
#  'though': 6572,
#  'idea': 3467,
#  'should': 5858,
#  'come': 1851,
#  'did': 2227,
#  'persons': 4953,
#  'story': 6225,
#  'yeah': 7360,
#  'we': 7103,
#  'totes': 6699,
#  'wanna': 7065,
#  'calling': 1565,
#  'lot': 4046,
#  'times': 6611,
#  'lil': 3956,
#  'busy': 1518,
#  'noon': 4617,
#  'wasn': 7079,
#  'paying': 4912,
#  'attention': 1083,
#  'morning': 4410,
#  'love': 4059,
#  'go': 3059,
#  'sleep': 5949,
#  'wish': 7221,
#  'day': 2109,
#  'full': 2948,
#  'feeling': 2725,
#  'better': 1286,
#  'opportunity': 4764,
#  'last': 3869,
#  'babe': 1144,
#  'kiss': 3805,
#  'drive': 2377,
#  'lor': 4040,
#  'huh': 3424,
#  'slow': 5968,
#  'tot': 6696,
#  'reach': 5354,
#  'ago': 836,
#  'liao': 3933,
#  'days': 2110,
#  'leh': 3916,
#  'dun': 2408,
#  'cut': 2061,
#  'short': 5849,
#  'like': 3950,
#  'failed': 2669,
#  'quite': 5295,
#  'sad': 5621,
#  'shopping': 5846,
#  'raining': 5314,
#  'mah': 4142,
#  'hard': 3227,
#  'leave': 3905,
#  'orchard': 4778,
#  'blame': 1334,
#  'life': 3941,
#  'give': 3046,
#  'happiness': 3225,
#  'bad': 1155,
#  'experience': 2637,
#  'essential': 2564,
#  'all': 877,
#  'gods': 3066,
#  'blessings': 1344,
#  'ok': 4715,
#  'april': 990,
#  'cant': 1587,
#  'wait': 7042,
#  'daddy': 2077,
#  'make': 4155,
#  'scream': 5698,
#  'pleasure': 5035,
#  'slap': 5947,
#  'ass': 1052,
#  'dick': 2224,
#  'yes': 7372,
#  'reg': 5424,
#  'ciao': 1761,
#  '2nd': 382,
#  'tried': 6742,
#  'won': 7255,
#  '1450': 288,
#  'prize': 5197,
#  'claim': 1768,
#  '09053750005': 165,
#  'b4': 1135,
#  '310303': 415,
#  'stop': 6214,
#  '08718725756': 135,
#  '140ppm': 286,
#  'told': 6655,
#  'gautham': 2992,
#  'someonone': 6029,
#  'trying': 6763,
#  'via': 6965,
#  'our': 4801,
#  'dating': 2105,
#  'service': 5770,
#  'find': 2770,
#  'who': 7181,
#  'could': 1965,
#  'be': 1228,
#  'landline': 3853,
#  '09064015307': 201,
#  'box334sk38ch': 1414,
#  'lazy': 3890,
#  'type': 6806,
#  'forgot': 2863,
#  'ì_': 7429,
#  'lect': 3908,
#  'saw': 5671,
#  'pouch': 5118,
#  'nice': 4577,
#  'man': 4163,
#  'wife': 7195,
#  'nt': 4652,
#  'parents': 4872,
#  'kids': 3793,
#  'went': 7147,
#  'work': 7268,
#  'even': 2578,
#  'colleagues': 1834,
#  'dearly': 2125,
#  'drop': 2382,
#  'tank': 6418,
#  'sunshine': 6320,
#  'hols': 3352,
#  'med': 4248,
#  'holiday': 3349,
#  'stamped': 6159,
#  'self': 5740,
#  'address': 784,
#  'envelope': 2538,
#  'drinks': 2375,
#  'us': 6905,
#  'uk': 6817,
#  'po': 5050,
#  '113': 259,
#  'bray': 1433,
#  'wicklow': 7191,
#  'eire': 2475,
#  'quiz': 5298,
#  'saturday': 5665,
#  'unsub': 6869,
#  'why': 7188,
#  'whats': 7165,
#  'indeed': 3531,
#  'by': 1534,
#  'way': 7098,
#  'either': 2476,
#  'bye': 1536,
#  'harish': 3232,
#  'rent': 5462,
#  'transfred': 6723,
#  'acnt': 762,
#  '800': 604,
#  'flights': 2811,
#  'europe': 2574,
#  'away': 1123,
#  '10th': 256,
#  'sept': 5764,
#  '09050000555': 156,
#  'ba128nnfwfly150ppm': 1141,
#  'hide': 3312,
#  'anythiing': 955,
#  'keeping': 3771,
#  'met': 4289,
#  'stranger': 6231,
#  'choose': 1750,
#  'world': 7275,
#  'stands': 6164,
#  'friendship': 2920,
#  'ends': 2504,
#  'lets': 3929,
#  'friends': 2918,
#  'forever': 2856,
#  'gud': 3162,
#  'nitz': 4598,
#  'welcome': 7140,
#  'date': 2102,
#  'msg': 4437,
#  'giving': 3048,
#  '08719839835': 149,
#  'future': 2962,
#  'mgs': 4292,
#  'billed': 1307,
#  '150p': 294,
#  'daily': 2079,
#  'cancel': 1580,
#  '89123': 678,
#  'hanks': 3213,
#  'lotsly': 4049,
#  'awarded': 1122,
#  'sipix': 5915,
#  'digital': 2243,
#  'camera': 1573,
#  '09061221061': 184,
#  'within': 7230,
#  '28days': 364,
#  'box177': 1410,
#  'm221bp': 4110,
#  '2yr': 399,
#  'warranty': 7077,
#  '150ppm': 298,
#  '16': 304,
#  'på': 5278,
#  '99': 704,
#  'wlcome': 7244,
#  'wonder': 7257,
#  'eaten': 2438,
#  'lion': 3973,
#  'nothing': 4638,
#  'yup': 7414,
#  'lol': 4019,
#  'they': 6546,
#  'don': 2328,
#  'awesome': 1124,
#  'click': 1787,
#  'delete': 2160,
#  'current': 2051,
#  'food': 2843,
#  'also': 889,
#  'wipro': 7217,
#  'get': 3021,
#  'thing': 6551,
#  'years': 7362,
#  'gentle': 3014,
#  'princess': 5187,
#  'sweet': 6364,
#  'poem': 5068,
#  'dear': 2122,
#  'near': 4531,
#  'dont': 2332,
#  'fear': 2716,
#  'cheer': 1709,
#  'ni8': 4575,
#  'yay': 7358,
#  'girls': 3043,
#  'esplanade': 2562,
#  'else': 2487,
#  'hope': 3371,
#  'had': 3184,
#  'hmmm': 3338,
#  'texted': 6501,
#  'showered': 5867,
#  'er': 2543,
#  'ything': 7408,
#  'enjoy': 2515,
#  'playing': 5028,
#  'football': 2848,
#  'basketball': 1199,
#  'anything': 957,
#  'outdoors': 4807,
#  'double': 2343,
#  'txts': 6801,
#  '6months': 570,
#  'bluetooth': 1362,
#  'orange': 4775,
#  'available': 1106,
#  'sony': 6047,
#  'motorola': 4419,
#  'phones': 4973,
#  'mobileupd8': 4370,
#  '08000839402': 47,
#  'call2optout': 1554,
#  'n9dx': 4489,
#  'evening': 2579,
#  'roger': 5562,
#  'wahala': 7038,
#  'need': 4541,
#  'accidentally': 747,
#  'brought': 1473,
#  'em': 2489,
#  'aight': 846,
#  'again': 826,
#  'comin': 1856,
#  'hey': 3306,
#  'tmr': 6636,
#  'maybe': 4231,
#  'meet': 4253,
#  'yck': 7359,
#  'lip': 3977,
#  'synced': 6382,
#  'shangela': 5800,
#  'needs': 4545,
#  'dat': 2100,
#  'slowly': 5970,
#  'vomit': 7010,
#  'lotr': 4047,
#  'sis': 5919,
#  'aft': 818,
#  'wan': 7062,
#  'dinner': 2252,
#  'nite': 4594,
#  'finally': 2767,
#  'completed': 1876,
#  'course': 1976,
#  'pick': 4983,
#  'possible': 5106,
#  'dint': 2254,
#  'happened': 3219,
#  'switch': 6374,
#  'off': 4693,
#  'cell': 1652,
#  'whole': 7182,
#  'isnt': 3617,
#  'care': 1600,
#  'alrite': 888,
#  'hunny': 3432,
#  'wot': 7285,
#  '2nite': 385,
#  'didnt': 2229,
#  'end': 2501,
#  'goin': 3070,
#  'down': 2350,
#  'town': 6706,
#  'jus': 3737,
#  'pub': 5252,
#  'instead': 3569,
#  'chillin': 1738,
#  'mo': 4362,
#  'bedroom': 1246,
#  'jen': 3679,
#  'wif': 7194,
#  'family': 2685,
#  'booking': 1383,
#  'tour': 6704,
#  'package': 4837,
#  'darren': 2097,
#  'saying': 5674,
#  'ge': 3003,
#  'den': 2172,
#  'cos': 1955,
#  'xy': 7345,
#  'feel': 2723,
#  'awkward': 1125,
#  'him': 3320,
#  'lunch': 4092,
#  'ten': 6475,
#  'shower': 5866,
#  'plan': 5015,
#  'coming': 1857,
#  'brum': 1480,
#  'putting': 5275,
#  '6times': 574,
#  'may': 4229,
#  'dreams': 2367,
#  'true': 6753,
#  'update': 6880,
#  'weed': 7124,
#  'dealer': 2119,
#  'freedom': 2897,
#  'lunsford': 4093,
#  'im': 3493,
#  'realy': 5373,
#  'soz': 6075,
#  'imat': 3495,
#  'mums': 4464,
#  '2moro': 375,
#  'ya': 7347,
#  'came': 1572,
#  're': 5353,
#  'restocked': 5509,
#  'badrith': 1158,
#  'chennai': 1716,
#  'surely': 6338,
#  'competition': 1871,
#  'thk': 6563,
#  'oso': 4791,
#  'boring': 1393,
#  'uniform': 6851,
#  'ask': 1042,
#  'macho': 4127,
#  'budget': 1492,
#  'bb': 1213,
#  'bold': 1373,
#  'dollars': 2324,
#  'tuesday': 6775,
#  'freemsg': 2902,
#  'buffy': 1495,
#  'satisfy': 5663,
#  'men': 4273,
#  'randy': 5331,
#  'pix': 5007,
#  'qlynnbv': 5283,
#  'help08700621170150p': 3286,
#  'he': 3255,
#  'priest': 5183,
#  've': 6951,
#  'joined': 3701,
#  'league': 3899,
#  'keep': 3770,
#  'touch': 6700,
#  'mean': 4239,
#  'deal': 2118,
#  'personal': 4950,
#  'cost': 1957,
#  'gain': 2969,
#  'rights': 5541,
#  'demand': 2171,
#  'husband': 3440,
#  'grumpy': 3156,
#  'mom': 4387,
#  'lying': 4105,
#  'play': 5023,
#  'jokes': 3705,
#  'oops': 4753,
#  'done': 2330,
#  'studyn': 6254,
#  'library': 3936,
#  'problem': 5202,
#  'baby': 1147,
#  'talk': 6409,
#  'called': 1559,
#  'left': 3910,
#  'message': 4283,
#  'yo': 7383,
#  'dude': 2401,
#  'guess': 3165,
#  'arrested': 1023,
#  'ha': 3181,
#  'same': 5641,
#  'watch': 7085,
#  'already': 886,
#  'haf': 3185,
#  'smth': 5996,
#  'mind': 4310,
#  'bomb': 1377,
#  'wanted': 7069,
#  'elaine': 2480,
#  'confirmed': 1904,
#  'sister': 5920,
#  'talking': 6412,
#  'damn': 2080,
#  'poor': 5087,
#  'zac': 7416,
#  'doesn': 2305,
#  'stand': 6161,
#  'knows': 3819,
#  'wants': 7071,
#  'questions': 5291,
#  'aathi': 718,
#  'hello': 3282,
#  'request': 5482,
#  'rs': 5587,
#  'transfered': 6721,
#  'derek': 2189,
#  'thank': 6512,
#  'wonderful': 7258,
#  'says': 5675,
#  'money': 4393,
#  'definitely': 2153,
#  'buying': 1527,
#  'before': 1255,
#  'significance': 5891,
#  'weekends': 7128,
#  'shows': 5871,
#  '900': 690,
#  'guaranteed': 3160,
#  '09061701939': 187,
#  'code': 1824,
#  's89': 5615,
#  'valid': 6933,
#  '12hrs': 278,
#  'meant': 4242,
#  'opposed': 4765,
#  'drunken': 2391,
#  'night': 4584,
#  'unless': 6861,
#  'book': 1381,
#  'kinda': 3800,
#  'joke': 3703,
#  'thet': 6544,
#  'were': 7150,
#  'really': 5372,
#  'looking': 4033,
#  'skinny': 5938,
#  'white': 7179,
#  'line': 3964,
#  'casting': 1626,
#  'look': 4030,
#  'hasn': 3238,
#  'pattern': 4904,
#  'recently': 5392,
#  'crap': 1993,
#  'prakesh': 5140,
#  'said': 5628,
#  'into': 3583,
#  'minute': 4323,
#  'sed': 5725,
#  'sexy': 5784,
#  'mood': 4404,
#  'minuts': 4325,
#  'latr': 3878,
#  'cake': 1544,
#  'speed': 6096,
#  'speedchat': 6097,
#  '80155': 611,
#  'swap': 6358,
#  'chatter': 1694,
#  'chat80155': 1692,
#  'pobox36504w45wq': 5058,
#  'rcd': 5347,
#  'hoping': 3378,
#  'langport': 3858,
#  'still': 6202,
#  'office': 4700,
#  'site': 5923,
#  'simulate': 5906,
#  'test': 6491,
#  'gives': 3047,
#  'very': 6962,
#  'tough': 6702,
#  'readiness': 5362,
#  'likely': 3952,
#  'mittelschmertz': 4348,
#  'google': 3094,
#  'paracetamol': 4867,
#  'worry': 7279,
#  'dunno': 2410,
#  'lei': 3917,
#  'shd': 5811,
#  'driving': 2380,
#  'sch': 5683,
#  'hr': 3410,
#  'oni': 4740,
#  'confuses': 1907,
#  'things': 6552,
#  'doesnt': 2306,
#  'wrong': 7306,
#  'sort': 6058,
#  'invited': 3589,
#  'tho': 6568,
#  'nvm': 4667,
#  'wear': 7107,
#  'sport': 6133,
#  'shoes': 5841,
#  'anyway': 959,
#  'late': 3872,
#  'spending': 6104,
#  'brother': 1471,
#  'next': 4574,
#  'ready': 5364,
#  'spoiled': 6123,
#  'escape': 2557,
#  'theatre': 6528,
#  'kavalan': 3765,
#  'few': 2738,
#  'minutes': 4324,
#  'consensus': 1915,
#  'cool': 1943,
#  'let': 3928,
#  'kicks': 3790,
#  'around': 1019,
#  'typical': 6808,
#  'doctors': 2299,
#  'reminds': 5454,
#  '2go': 371,
#  'little': 3988,
#  'lounge': 4055,
#  'liked': 3951,
#  'photos': 4976,
#  'pity': 5006,
#  'suggestions': 6300,
#  'yet': 7375,
#  'easiest': 2431,
#  'barcelona': 1184,
#  'ru': 5592,
#  'house': 3398,
#  'looks': 4034,
#  'scrumptious': 5704,
#  'eat': 2437,
#  'ûò': 7439,
#  'entertaining': 2527,
#  'getting': 3027,
#  'hugh': 3422,
#  'laurie': 3883,
#  'stick': 6200,
#  'especially': 2561,
#  'apart': 962,
#  'yesterday': 7374,
#  'happen': 3217,
#  'silent': 5896,
#  'tensed': 6478,
#  'prabha': 5132,
#  'soryda': 6064,
#  'frm': 2923,
#  'sory': 6063,
#  'noe': 4604,
#  'la': 3833,
#  'wana': 7064,
#  'pei': 4926,
#  'bf': 1293,
#  'rite': 5550,
#  'round': 5578,
#  'til': 6607,
#  'ish': 3612,
#  'apologetic': 967,
#  'fallen': 2679,
#  'actin': 766,
#  'spoilt': 6124,
#  'child': 1730,
#  'caught': 1634,
#  'till': 6608,
#  'badly': 1157,
#  'cheers': 1711,
#  'sir': 5917,
#  'receive': 5388,
#  'account': 754,
#  '1hr': 315,
#  'delay': 2158,
#  'month': 4400,
#  'upto': 6891,
#  'calls': 1567,
#  'standard': 6162,
#  'charge': 1680,
#  'activate': 770,
#  '9061100010': 691,
#  'wire3': 7218,
#  'net': 4556,
#  '1st4terms': 320,
#  'pobox84': 5061,
#  'm26': 4112,
#  '3uz': 447,
#  'mobcudb': 4365,
#  'gimme': 3037,
#  'caveboy': 1638,
#  'garage': 2982,
#  'keys': 3782,
#  'aren': 1002,
#  'bookshelf': 1386,
#  'swhrt': 6369,
#  'dey': 2214,
#  '2day': 366,
#  'miss': 4334,
#  'mad': 4130,
#  'found': 2880,
#  'diff': 2237,
#  'farm': 2696,
#  'shop': 5844,
#  'some': 6024,
#  'cheese': 1713,
#  'gonna': 3080,
#  'rip': 5548,
#  'uterus': 6921,
#  'rimac': 5543,
#  'access': 743,
#  'somewhere': 6039,
#  'beneath': 1276,
#  'pale': 4849,
#  'moon': 4405,
#  'light': 3947,
#  'someone': 6028,
#  'goodnite': 3089,
#  'meh': 4259,
#  'join': 3700,
#  'bus': 1513,
#  'ìï': 7431,
#  'ericsson': 2546,
#  'cannot': 1586,
#  'oredi': 4781,
#  'lar': 3863,
#  'asked': 1044,
#  'search': 5709,
#  'login': 4014,
#  'todays': 6646,
#  'voda': 7004,
#  'numbers': 4661,
#  'ending': 2503,
#  '5226': 517,
#  '350': 422,
#  'award': 1121,
#  ...}

# %%
len(cvect.vocabulary_)
# Out:
# 7441

# %%
#Build Document Term Matrix DTM 
#  
x_train = cvect.transform(sms_train)
x_train.shape
# Out:
# (4179, 7441)

# %%
sms_train[0]
# Out:
# 'U can call now...'

# %%
x_train[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 3 stored elements and shape (1, 7441)>

# %%
print(x_train[0:1])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 3 stored elements and shape (1, 7441)>
#   Coords	Values
#   (0, 1552)	1
#   (0, 1576)	1
#   (0, 4648)	1

# %%
x_test = cvect.transform(sms_test)
x_test.shape
# Out:
# (1393, 7441)

# %%
# Building an SMS Classifier

from sklearn.neighbors import KNeighborsClassifier
kknn = KNeighborsClassifier(n_neighbors=5)
kknn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Evaluation on Test Dataset 

from sklearn import metrics
metrics.accuracy_score(y_test, kknn.predict(x_test))
# Out:
# 0.914572864321608

# %%
metrics.accuracy_score(y_train, kknn.predict(x_train))
# Out:
# 0.9294089495094521

# %%
#classifier using SVM

from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(x_train, y_train)
metrics.accuracy_score(y_test, svm.predict(x_test))
metrics.accuracy_score(y_train, svm.predict(x_train))
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
metrics.accuracy_score(y_test, rf_model.predict(x_test))
# Out:
# 0.9727207465900933

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tvect = TfidfVectorizer()
tvect.fit(sms_train)
# Out:
# TfidfVectorizer()

# %%
len(tvect.vocabulary_)
# Out:
# 7441

# %%
x_train_tfidf = tvect.transform(sms_train)
x_train_tfidf.shape
# Out:
# (4179, 7441)

# %%
print(x_train_tfidf[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3 stored elements and shape (1, 7441)>
#   Coords	Values
#   (0, 1552)	0.5542520595511462
#   (0, 1576)	0.6054718381449722
#   (0, 4648)	0.5711466604092693

# %%
x_test_tfidf = tvect.transform(sms_test)
x_test_tfidf.shape
# Out:
# (1393, 7441)

# %%
# now we apply with Random Forest Classifier
rf_model_tfidf = RandomForestClassifier()
rf_model_tfidf.fit(x_train_tfidf, y_train)
metrics.accuracy_score(y_test, rf_model_tfidf.predict(x_test_tfidf))
# Out:
# 0.9755922469490309
