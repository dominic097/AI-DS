# %%
# Install spacy
# !pip install spacy
# Out:
# Collecting spacy
#   Using cached spacy-3.8.11-cp313-cp313-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.15-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.13-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.12-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Using cached thinc-8.3.10-cp313-cp313-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.5.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Using cached weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from spacy) (2.32.5)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from spacy)
#   Using cached setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from spacy) (26.0)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached blis-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer>=0.24.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.0)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Using cached smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy)
#   Downloading wrapt-2.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: click>=8.2.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/damirdarasu/Library/CloudStorage/OneDrive-Aziro/mynotebook/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Using cached spacy-3.8.11-cp313-cp313-macosx_11_0_arm64.whl (5.7 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.13-cp313-cp313-macosx_11_0_arm64.whl (42 kB)
# Using cached murmurhash-1.0.15-cp313-cp313-macosx_11_0_arm64.whl (27 kB)
# Using cached preshed-3.0.12-cp313-cp313-macosx_11_0_arm64.whl (122 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.2-cp313-cp313-macosx_11_0_arm64.whl (651 kB)
# Using cached thinc-8.3.10-cp313-cp313-macosx_11_0_arm64.whl (737 kB)
# Using cached blis-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (1.2 MB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.3-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached smart_open-7.5.0-py3-none-any.whl (63 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Using cached setuptools-82.0.0-py3-none-any.whl (1.0 MB)
# Downloading wrapt-2.1.1-cp313-cp313-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, wasabi, typing-inspection, spacy-loggers, spacy-legacy, setuptools, pydantic-core, murmurhash, MarkupSafe, cymem, cloudpathlib, catalogue, blis, annotated-types, srsly, smart-open, pydantic, preshed, jinja2, confection, thinc, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [spacy]m22/23 [spacy]]c]s]
# Successfully installed MarkupSafe-3.0.3 annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 jinja2-3.1.6 murmurhash-1.0.15 preshed-3.0.12 pydantic-2.12.5 pydantic-core-2.41.5 setuptools-82.0.0 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typing-inspection-0.4.2 wasabi-1.1.3 weasel-0.4.3 wrapt-2.1.1

# %%
# Download the English language model
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 15.9 MB/s  0:00:00eta 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

def lemmatize_text(text):
    doc = nlp(text)
    print([(token.text, token.lemma_) for token in doc])

    lemmatized_text = " ".join([token.lemma_ for token in doc])
    print(lemmatized_text)
    
    return lemmatized_text

lemmatize_text("My name is Damir and I am running in the park. I have better running shoes than you.")
# Out:
# [('My', 'my'), ('name', 'name'), ('is', 'be'), ('Damir', 'Damir'), ('and', 'and'), ('I', 'I'), ('am', 'be'), ('running', 'run'), ('in', 'in'), ('the', 'the'), ('park', 'park'), ('.', '.'), ('I', 'I'), ('have', 'have'), ('better', 'well'), ('running', 'run'), ('shoes', 'shoe'), ('than', 'than'), ('you', 'you'), ('.', '.')]
# my name be Damir and I be run in the park . I have well run shoe than you .
# 'my name be Damir and I be run in the park . I have well run shoe than you .'
