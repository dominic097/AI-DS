# %%
# !pip install nltk

import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')


def simple_preprocess(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Tokenize the text
    tokens = word_tokenize(text)

    print("Tokens after tokenization:", tokens)
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    print("Tokens after stop words removal:", tokens)
    
    # Stemming
    porter_stemmer = PorterStemmer()
    tokens = [porter_stemmer.stem(word) for word in tokens]
    print("Tokens after stemming:", tokens)
    
    return ' '.join(tokens)

simple_preprocess("Hello! This is a simple text preprocessing example. Let's see how it works.")
# Out:
# Tokens after tokenization: ['hello', 'this', 'is', 'a', 'simple', 'text', 'preprocessing', 'example', 'lets', 'see', 'how', 'it', 'works']
# Tokens after stop words removal: ['hello', 'simple', 'text', 'preprocessing', 'example', 'lets', 'see', 'works']
# Tokens after stemming: ['hello', 'simpl', 'text', 'preprocess', 'exampl', 'let', 'see', 'work']
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'hello simpl text preprocess exampl let see work'
