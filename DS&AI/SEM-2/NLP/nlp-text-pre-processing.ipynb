# %%
def to_lowercase(text):
    """
    Convert text to lowercase as part of text normalization
    """
    return text.lower()

# Example usage
to_lowercase("<html> Natural Language Processing is AWESOME! </html>")
# Out:
# '<html> natural language processing is awesome! </html>'

# %%
# !pip install bs4

from bs4 import BeautifulSoup

def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text
    
strip_html_tags("<html><h2>Some important text</h2></html>")
# Out:
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [bs4]
# ...
# 'Some important text'

# %%
import re
def remove_special_characters (text, remove_digits=False):
  #Using regex
  if remove_digits:
    pattern = r'[^a-zA-Z\s]'
  else:
    pattern = r'[^a-zA-Z0-9\s]'
  text = re.sub(pattern, '', text)
  return text

remove_special_characters('Sómě Áccentěd těxt')
# Out:
# 'Sm ccentd txt'

# %%
# !pip install unidecode
from unidecode import unidecode

text = "À la carte, café, Niño, Über"
normalized_text = unidecode(text)
print(normalized_text)
# Out:
# ...
# A la carte, cafe, Nino, Uber

# %%
# !pip install emoji

import emoji
input_text='He is 😊 '
output_text=emoji.demojize(input_text)
output_text
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 2.7 MB/s  0:00:00
# ...
# 'He is :smiling_face_with_smiling_eyes: '

# %%
# !pip install nltk

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached regex-2026.1.15-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 779.6 kB/s  0:00:01 eta 0:00:01
# Using cached regex-2026.1.15-cp313-cp313-macosx_11_0_arm64.whl (288 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [nltk]4/5 [nltk]b]
# ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt_tab')

print(stopwords.words('english'))

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Sample text
text = "This is a simple example to demonstrate removing stop words using NLTK."

# Tokenize the text
words = word_tokenize(text)

# Get the list of stopwords for English
stop_words = set(stopwords.words('english'))

# Remove stopwords
filtered_words = [word for word in words if word.lower() not in stop_words] # word.lower() not in stop_words,  ensures the lowercase word isn't in the stop_words collection.

print("Original Text:", text)
print("Filtered Text:", " ".join(filtered_words))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
def lemmatize_text(text):
  lemmatizer = WordNetLemmatizer()
  return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

lemmatize_text("The striped bats are hanging on their feet for best")
lemmatize_text("My system keeps crashing, his crashed yesterday, ours crashes daily")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/damirdarasu/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 'The striped bat are hanging on their foot for best'

# %%
from nltk.stem import WordNetLemmatizer

def simple_stemmer(text):
  ps = nltk.porter.PorterStemmer()
  text = ' '.join([ps.stem(word) for word in text.split()])
  return text

simple_stemmer("My system keeps crashing, his crashed yesterday, ours crashes daily")

# %%
#Install Spacy
# !pip install spacy --quiet
# !python -m spacy download en_core_web_sm
import spacy
nlp=spacy.load("en_core_web_sm")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.7 MB/s  0:00:07 eta 0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Example text
text="Barack Obama is an American politician who served as the 44th President of the United States from 2009 to 2017. He is the first African American to have served as president, as well as the first born outside the contiguous United States."

doc3=nlp(text)
from spacy import displacy
displacy.render(doc3, style='ent', jupyter=True)
# Extract entities
entities = [(ent.text, ent.label_) for ent in doc3.ents]
print(entities)
# Out:
#   Cell In[21], line 10
#     lemmatize_text("My system keeps crashing, his crashed yesterday, ours crashes daily")doc3=nlp(text)
#                                                                                          ^
# SyntaxError: invalid syntax

# %%
# !pip install pandas
import pandas as pd
# Example: Creating a DataFrame
data = []
for ent in doc3.ents:
    data.append({"Entity": ent.text, "Label": ent.label_})
df = pd.DataFrame(data)
print(df)

#Process a sentence
doc = nlp('She saw a bear. She was very afraid.')

type(doc)
#Print POS tags for each word 2 for word in doc:
for word in doc:
  print (word, word.pos_)
# Out:
# ...
#   Using cached pandas-3.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 2.4 MB/s  0:00:04m0:00:0100:01
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 # Example: Creating a DataFrame
#       4 data = []
# ----> 5 for ent in doc3.ents:
#       6     data.append({"Entity": ent.text, "Label": ent.label_})
#       7 df = pd.DataFrame(data)
#
# NameError: name 'doc3' is not defined
